# %%
# Out:
# ['3 5 6']

# %% [markdown]
# n = int(input())
# l = []
#
# for i in range(n):
#     x = int(input())
#     if x % 2 != 0:
#         l.append(x)
#     else:
#         continue
# print(l)
